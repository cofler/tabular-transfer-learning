# %%
import pickle
import csv
import pandas

normalizer = pickle.load(open("C:\\Users\\utente\\tabular-transfer-learning\\data\\eubuccoNLD_direct\\normalizer.pkl", 'rb'))
csvfile = pandas.read_csv("C:\\Users\\utente\\tabular-transfer-learning\\outputs\\from_scratch_default\\training-ft_transformer-eubuccoNLD_direct\\predictions_5.csv"
                          , names = ["preds"])
csvfile.head()

normalizer.var_
# Out:
# array([5.09194976e+04, 1.33994272e+05, 1.01126253e-02, 3.83604516e-03,
#        4.60847957e+04, 4.62533316e+04, 8.20644867e-08, 1.12181208e+00,
#        4.25215042e+04, 4.24230961e+07, 1.66667124e-02, 8.83471662e+05,
#        6.24481193e+03, 4.14334417e-08, 1.29967591e+06, 2.21730899e+01,
#        7.74533085e+04, 7.34626502e+04, 2.74271183e+01, 5.23035930e-04,
#        6.81407398e+12, 5.00012455e+05, 4.24781366e-02, 1.09147152e+02,
#        9.86681337e-08, 2.53156374e+05, 5.04961281e+01, 4.05349716e+05,
#        9.96288525e+02, 1.54284655e-07, 3.81260775e+01, 1.03503067e+02,
#        5.64753908e+02, 2.21016457e+04, 5.91978060e-03, 2.56695290e+04,
#        1.88992870e+13, 7.21619897e+01, 7.14084267e+05, 1.75924825e-04,
#        1.95792715e+01, 1.02374308e+02, 5.75384909e+03, 1.97663637e+02,
#        2.14958558e+07, 1.63866000e+00, 3.03043384e+01, 5.00063512e+12,
#        1.40781878e+02, 1.66118835e-02, 6.85690202e-01, 3.42976536e-03,
# ...
